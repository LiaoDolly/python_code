# %% [markdown]
# # chpter I

# %% [markdown]
# ###  show the basic way of crawling

# %%
# 1
#textbook's way~~


from urllib.request import urlopen
#Retrieve HTML string from the URL
html = urlopen("http://www.pythonscraping.com/exercises/exercise1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
#practice

from urllib.request import urlopen

html = urlopen('https://www.taiwanhot.net/?p=470988')

print(html.read())
# Out:
# b'<!DOCTYPE html>\n<html lang="zh-TW">\n<head>\n    <title> | \xe5\x8f\xb0\xe7\x81\xa3\xe5\xa5\xbd\xe6\x96\xb0\xe8\x81\x9e TaiwanHot.net</title>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="width=device-width, initial-scale=1 ,user-scalable=no" >\n    <meta name="keyword" content=" \xe9\x8b\x92\xe9\x9d\xa2 \xe
# ...

# %%
#2

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/exercises/exercise1.html")
bsObj = BeautifulSoup(html.read(),'lxml')
print(bsObj.h1)
# Out:
# <h1>An Interesting Title</h1>

# %%
#practice-1

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://zh.wikipedia.org/wiki/Wiki')
bsObj = BeautifulSoup(html.read(),'lxml')
bsObj.h1
# Out:
# <h1 class="firstHeading" id="firstHeading" lang="zh">Wiki</h1>

# %%
#practice-2 another way(teacher in goint to use)

import requests
from bs4 import BeautifulSoup

res = requests.get('https://zh.wikipedia.org/wiki/Wiki')
soup = BeautifulSoup(res.text,'lxml')
#soup
soup.select('h1')
# Out:
# [<h1 class="firstHeading" id="firstHeading" lang="zh">Wiki</h1>]

# %%
#3

from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import sys


def getTitle(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        print(e)
        return None
    try:
        bsObj = BeautifulSoup(html.read(),'lxml')
        title = bsObj.body.h1
    except AttributeError as e:
        return None
    return title

title = getTitle("http://www.pythonscraping.com/exercises/exercise1.html")
if title == None:
    print("Title could not be found")
else:
    print(title)
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# # Chapter II

# %% [markdown]
# ### how to use    text()  、 get_text()  、findAll()、find() 、select()、next_sibling(s)、previous_sibling(s)
# ### diffrentent way for nasic crawling
#
# ### select --> List    、 find   -->  tag、findAll  -->ResultSet
#
# ### the definition of children and descendant
#
# ### RexgexPal --> re.compile(..)

# %%
#urlopen出來的物件，不用html.text轉變型態，但要html.read()

#1

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/warandpeace.html")
bsObj = BeautifulSoup(html.read(), "html.parser")

nameList = bsObj.findAll("span", {"class":"green"})
        #findAll : find out all tag named 'span' and class called green at the same time .
for name in nameList:                  
    print(name.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#practice-1
import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.pythonscraping.com/pages/warandpeace.html')

soup = BeautifulSoup(res.text,'lxml')


soupp = soup.findAll('span',{'class':'green'})
for sou in soupp:
    print(sou.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#practice-2
import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.pythonscraping.com/pages/warandpeace.html')

soup = BeautifulSoup(res.text,'lxml')


soupp = soup.select('span' '.green')
for sou in soupp:
    print(sou.text)

#the wat upper:
#soupp = soup.findAll('span',{'class':'green'})
#for sou in soupp:
#    print(sou.get_text())


#whenever XXX.text or XXX.get_text() exist, it means the end of the program.
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#practice-3

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/warandpeace.html")
bsObj = BeautifulSoup(html.read(), "lxml")

nameList = bsObj.find("span", {"class":"green"})
                        #find: find out the first span and its class named green.
nameList
# Out:
# <span class="green">Anna
# Pavlovna Scherer</span>

# %%
#practice-4

import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.pythonscraping.com/pages/warandpeace.html')
soup = BeautifulSoup(res.text,'lxml')

green = soup.find('span',{'class':'green'})
green
# Out:
# <span class="green">Anna
# Pavlovna Scherer</span>

# %%
#2

#select --> List
#find   -->  tag
#findAll  -->ResultSet


from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/warandpeace.html")
bsObj = BeautifulSoup(html.read(), "html.parser")


allText = bsObj.findAll(id="text") 
#allText = bsObj.find(id="text")
#allText = bsObj.select('#text')   #the same effect

print(type(allText))

#allText     #mixed with tag


print(allText[0].get_text())    #for findAll and select
#print(allText.get_text())      #for find
# Out:
# <class 'list'>
#
# "Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news."
#
# It was in July, 1805, and the speaker was the well-known Anna
# Pavlovna Scherer, maid of honor and favorite of the Empress Marya
# Fedorovna. With these words she greeted Prince Vasili Kuragin, a man
# of high rank and importance, who was the first to arrive at her
# reception. Anna Pavlovna had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
# St. Petersburg, used only by the elite.
#
# ...

# %%
#3  graduall construction of tags could be portraied as the relationship of children & descendants.
                                #children means the next layer of parent tag
                                #descendant means the all layers from parent tag

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html, "html.parser")

for child in bsObj.find("table",{"id":"giftList"}).children:
#for child in bsObj.find("table",{"id":"giftList"}).descendants:

    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <th>
# Item Title
# </th>
#
# Item Title
#
# <th>
# Description
# </th>
#
# Description
#
# <th>
# Cost
# </th>
#
# Cost
#
# <th>
# Image
# </th>
#
# Image
#
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <td>
# Vegetable Basket
# </td>
#
# Vegetable Basket
#
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>
#
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# ...

# %%
#4    #next_sibling's'  is a method.  keeping acquiring elements 

from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html, "html.parser")

for sibling in bsObj.find("table",{"id":"giftList"}).tr.next_siblings: # crawling from tbody's tr to next layor
                            # find out the first tag named table and id named giftList.
                            # keep crawling info due to calling next_siblings method.
#for sibling in bsObj.find("table",{"id":"giftList"}).tr:
                            #therefore, only show off tr in id named giftList's part.
    
#for sibling in bsObj.find("table",{"id":"giftList"}):
                            #find out all table information
    print(sibling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %%
#5 previous_sibling is a method.  not like next_siblings, previous_sibling only acquire elements once.

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html, "html.parser")
print(bsObj.find("img",{"src":"../img/gifts/img1.jpg"}).parent.previous_sibling.get_text())
# Out:
# $15.00

# %%
#6 import re  means using RegexPal

#the way to represent RegexPal in program is typing  re.compile(..............)

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html, "html.parser")
images = bsObj.findAll("img", {"src":re.compile("\.\.\/img\/gifts/img.*\.jpg")})
                                       # RegexPl../img/gifts/img(any).jpg
for image in images: 
    print(image["src"])
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %% [markdown]
# # Chapter III

# %% [markdown]
# ###  how to use    attre、attrs
# ###   print all effective a-link on one page
#
# ### print all effective a-link on one page "randomly"
#
# ###  print all effective a-link on one page "no repeatly"
#
# ### crawling the site and listing tag element at meantime

# %%
#Page 32   print all a-link on one website

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html, 'lxml')


                        #get all the orginal url on one website 
for link in bsObj.findAll('a'):    
                       #how to use attrs
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/San_Diego_Comic-Con
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com/
# #cite_note-1
# #cite_note-actor-2
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-3
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-4
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-5
# #Early_life_and_education
# #Acting_career
# #Early_work
# ...

# %%
#backup for page 32

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html, 'lxml')

link  = bsObj.findAll('a')
#type(link)
print(link)
# Out:
# [<a id="top"></a>, <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected to promote compliance with the policy on biographies of living people"><img alt="Page semi-protected" data-file-height="128" data-file-width="128" height="20" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Padlock-silver.svg/20px-Padlock-silver.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Padlock-silver.svg/30px-Padlock-silver.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Padlock-silver.svg/40px-Padlock-silver.svg.png 2x" width="20"/></a>, <a href="#mw-head">navigation</a>, <a href="#p-search">search</a>, <a class="mw-disambig" href="/wiki/Kevin_Bacon_(disambiguation)" title="Kevin Bacon (disambiguation)">Kevin Bacon (disambiguation)</a>, <a class="image" href="/wiki/File:Kevin_Bacon_SDCC_2014.jpg"><img alt="Kevin Bacon SDCC 2014.jpg" data-file-height="2649" data-file-width="1907" height="306" src="//upload.wikimedia.org/wikip
# ...

# %%
#practice-1

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://udn.com/news/story/7002/2564595")
bsObj = BeautifulSoup(html, 'lxml')

for link in bsObj.findAll('a'):
    
                       #how to use attrs
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# https://shopping.udn.com/mall/Cc1a00.do?sid=91_udn&utm_source=udn.com&utm_medium=referral_familybar_udn&utm_term=familybar_udn&utm_campaign=20150103_UDN
# https://udesign.udnfunlife.com/mall/Cc1a00.do?sid=91_udn&utm_source=udn.com&utm_medium=referral_familybar_udn&utm_term=familybar_udn&utm_campaign=20170118_UDN
# https://tickets.udnfunlife.com/application/utk01/utk0101_.aspx?sid=91_udn&utm_source=udn.com&utm_medium=referral_familybar_udn&utm_term=familybar_udn&utm_campaign=20170118_UDN
# /rssfeed/lists/2
# https://mobile.udn.com/
# https://www.facebook.com/myudn
# https://udn.com/mypage/
# javascript:void(0);
# javascript:void(0);
# #header_menu_area
# javascript:void(0);
# https://shopping.udn.com/mall/cus/adv/M_Cc1d01.do?sid=91_logo_m&utm_source=udn.com&utm_medium=referral_baglogo_m&utm_term=baglogo_m&utm_campaign=20150103_UDN
# /
# /
# https://style.udn.com/?familybar_show
# https://autos.udn.com/?familybar_show
# https://nba.udn.com/?familybar_show
# ...

# %%
#page 33   print all effective a-link on one page

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bsObj = BeautifulSoup(html, 'lxml')

for link in bsObj.find('div',{'id':'bodyContent'} ).findAll('a', href = re.compile("^(/wiki)((?!:).)*$")):
                                                                # no "href", cause it's an attribute.
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/San_Diego_Comic-Con
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# ...

# %%
#practice-1

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://zh.wikipedia.org/wiki/%E6%96%87%E6%96%AF%C2%B7%E5%8D%A1%E7%89%B9')

bsObj = BeautifulSoup(html.read(),'lxml')

for soup in bsObj.find('div',{'id':'bodyContent'}).findAll('a', href = re.compile("^(/wiki)((?!:).)*$")):
    if 'href' in soup.attrs:
        print(soup.attrs['href'])
# Out:
# /wiki/%E4%BD%9B%E7%BE%85%E9%87%8C%E9%81%94%E5%B7%9E
# /wiki/%E4%BB%A3%E6%89%98%E7%BA%B3%E6%AF%94%E5%A5%87_(%E4%BD%9B%E7%BD%97%E9%87%8C%E8%BE%BE%E5%B7%9E)
# /wiki/%E7%BE%8E%E5%9C%8B
# /wiki/%E5%8C%97%E5%8D%A1%E7%BE%85%E4%BE%86%E7%B4%8D%E5%A4%A7%E5%AD%B8
# /wiki/NBA%E9%81%B8%E7%A7%80
# /wiki/1998%E5%B9%B4NBA%E9%80%89%E7%A7%80
# /wiki/%E9%87%91%E5%B7%9E%E5%8B%87%E5%A3%AB%E9%98%9F
# /wiki/%E5%BE%97%E5%88%86%E5%BE%8C%E8%A1%9B
# /wiki/%E5%B0%8F%E5%89%8D%E9%8B%92
# /wiki/1998-99_NBA%E8%B3%BD%E5%AD%A3
# /wiki/2004-05_NBA%E8%B3%BD%E5%AD%A3
# /wiki/%E5%A4%9A%E4%BC%A6%E5%A4%9A%E7%8C%9B%E9%BE%99
# /wiki/2004-05_NBA%E8%B3%BD%E5%AD%A3
# /wiki/2008-09_NBA%E8%B3%BD%E5%AD%A3
# /wiki/%E5%B8%83%E9%B2%81%E5%85%8B%E6%9E%97%E7%AF%AE%E7%BD%91
# /wiki/2009-10_NBA%E8%B5%9B%E5%AD%A3
# /wiki/2010-11_NBA%E8%B3%BD%E5%AD%A3
# /wiki/%E5%A5%A5%E5%85%B0%E5%A4%9A%E9%AD%94%E6%9C%AF
# /wiki/2010-11_NBA%E8%B3%BD%E5%AD%A3
# /wiki/%E8%8F%B2%E5%B0%BC%E5%85%8B%E6%96%AF%E5%A4%AA%E9%98%B3
# ...

# %%
#practice-2

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://zh.wikipedia.org/wiki/%E7%A7%91%E6%AF%94%C2%B7%E5%B8%83%E8%8E%B1%E6%81%A9%E7%89%B9')

bsObj = BeautifulSoup(html.read(),'lxml')

for soup in bsObj.find('div',{'id':'bodyContent'}).findAll('a', href = re.compile("^(/wiki)((?!:).)*$")):
    if 'href' in soup.attrs:
        print(soup.attrs['href'])
# Out:
# /wiki/%E5%BE%97%E5%88%86%E5%BE%8C%E8%A1%9B
# /wiki/%E7%BE%8E%E5%9C%8B
# /wiki/%E5%AE%BE%E8%A5%BF%E6%B3%95%E5%B0%BC%E4%BA%9A%E5%B7%9E
# /wiki/%E8%B4%B9%E5%9F%8E
# /wiki/%E7%BE%8E%E5%9C%8B
# /wiki/-
# /wiki/-
# /wiki/NBA%E9%81%B8%E7%A7%80
# /wiki/1996%E5%B9%B4NBA%E9%81%B8%E7%A7%80
# /wiki/%E5%A4%8F%E6%B4%9B%E7%89%B9%E9%BB%83%E8%9C%82
# /wiki/1996-97_NBA%E8%B3%BD%E5%AD%A3
# /wiki/2015-16_NBA%E8%B5%9B%E5%AD%A3
# /wiki/%E6%B4%9B%E6%9D%89%E7%9F%B6%E6%B9%96%E4%BA%BA
# /wiki/NBA%E6%80%BB%E5%86%A0%E5%86%9B
# /wiki/NBA%E6%80%BB%E5%86%B3%E8%B5%9BMVP
# /wiki/NBA%E5%B9%B4%E5%BA%A6MVP
# /wiki/NBA%E6%98%8E%E6%98%9F%E8%B3%BD
# /wiki/NBA%E6%98%8E%E6%98%9F%E8%B3%BDMVP
# /wiki/NBA%E4%BE%8B%E8%A1%8C%E8%B3%BD%E5%BE%97%E5%88%86%E7%8E%8B
# /wiki/NBA%E6%9C%80%E4%BD%B3%E9%99%A3%E5%AE%B9
# /wiki/NBA%E6%9C%80%E4%BD%B3%E9%98%B2%E5%AE%88%E9%99%A3%E5%AE%B9
# /wiki/NBA%E7%81%8C%E7%B1%83%E5%A4%A7%E8%B3%BD
# ...

# %%
#1   挑選當下頁面上，任一個連結來顯示

from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())

def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bsObj = BeautifulSoup(html, "html.parser")
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))


links = getLinks("/wiki/Kevin_Bacon")
while len(links) > 0:
    
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
                   # http://en.wikipedia.org/wiki/Kevin_Bacon 頁面上，任選一個連結
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Proposition_8
# /wiki/California_gubernatorial_election,_1978
# /wiki/Los_Angeles_County_Board_of_Supervisors_election,_1996
# /wiki/United_States_House_of_Representatives_elections_in_California,_2014
# /wiki/California%27s_43rd_congressional_district
# /wiki/California%27s_42nd_congressional_district
# /wiki/California%27s_7th_congressional_district
# /wiki/John_H._Tolan
# /wiki/Copyright_status_of_work_by_the_U.S._government
# /wiki/Title_50_of_the_United_States_Code
# /wiki/Council_of_National_Defense
# /wiki/National_Defense_Research_Committee
# /wiki/Karl_Compton
# /wiki/American_Institute_of_Physics
# /wiki/Optical_Society
# /wiki/Gary_C._Bjorklund
# /wiki/Optical_Society_of_America#Past_Presidents_of_the_OSA
# /wiki/Robert_L._Byer
# /wiki/John_Archibald_Wheeler
# /wiki/Rita_Levi-Montalcini
# /wiki/Polytechnic_University_of_Turin
# /wiki/RWTH_Aachen_University
# /wiki/University_of_Augsburg
# /wiki/Philosophy
# /wiki/Aurobindo
# ...

# %%
#backup for #1

from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

print(datetime.datetime.now())
# Out:
# 2017-07-05 13:14:58.181082

# %%
#practice-2

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random
import requests


random.seed(datetime.datetime.now())

def getLinks(articleUrl):
    res = requests.get('https://zh.wikipedia.org'+articleUrl)
    soup = BeautifulSoup(res.text,'lxml')
    return soup.find('div',{'id':'bodyContent'}).findAll('a', href=re.compile("^(/wiki/)((?!:).)*$"))
                       

link = getLinks('/wiki/科比·布莱恩特')
while len(link) > 0:
    newArticle = link[random.randint(0,len(link)-1)].attrs['href']
        
    print(newArticle)
    link = getLinks(newArticle)
# Out:
# /wiki/SAT
# /wiki/%E9%A2%86%E4%BA%8B%E9%A6%86
# /wiki/%E4%BE%A8%E6%B0%91
# /wiki/%E6%B3%95%E5%9C%8B
# /wiki/%E5%A2%A8%E8%A5%BF%E5%93%A5
# /wiki/%E4%B8%AD%E9%9D%9E%E5%85%B1%E5%92%8C%E5%9B%BD
# /wiki/%E4%B9%8D%E5%BE%97
# /wiki/%E7%BB%B4%E5%9F%BA%E5%85%B1%E4%BA%AB%E8%B5%84%E6%BA%90
# /wiki/%E7%BB%B4%E5%9F%BA%E6%95%B0%E6%8D%AE
# /wiki/Alexa_Internet
# /wiki/%E4%BA%9E%E9%A6%AC%E9%81%9C%E7%B6%B2%E8%B7%AF%E6%9C%8D%E5%8B%99%E7%B3%BB%E7%B5%B1
# /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%BD%91%E7%BB%9C
# /wiki/ZigBee
# /wiki/Wi-Fi
# /wiki/Li-Fi
# /wiki/%E5%8F%AF%E8%A7%81%E5%85%89%E9%80%9A%E8%AE%AF%E6%8A%80%E6%9C%AF
# /wiki/%E5%8F%91%E5%85%89%E4%BA%8C%E6%9E%81%E7%AE%A1
# /wiki/%E7%A3%B7%E5%8C%96%E9%8E%B5
# /wiki/%E7%A0%B7%E5%8C%96%E9%8E%B5
# /wiki/%E7%A3%B7%E5%8C%96%E9%8A%A6%E9%8E%B5
# /wiki/%E7%9F%BD
# /wiki/%E9%92%8B
# /wiki/%E9%95%85
# /wiki/%E9%89%A8
# /wiki/P%E5%8C%BA%E5%85%83%E7%B4%A0
# /wiki/%E7%A1%92
# /wiki/%F0%A8%A7%80
# /wiki/%E9%92%9B
# /wiki/%E6%B1%9E
# ...

# %%
#P.37  #/wiki/開頭的網址都走訪   similar to google

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
        #no repeat
def getLinks(pageUrl):
    global pages
    #morepowerful than return. make pages works whole region
    
    html = urlopen("http://en.wikipedia.org"+ pageUrl)
    bsObj = BeautifulSoup(html,'lxml')
    
    for link in bsObj.findAll("a", href = re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #face new page
                newPage = link.attrs['href']
                                    #newPage is only equal pageUrl
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")  # first page
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Requesting_copyright_permission
# /wiki/Wikipedia:User_access_levels
# /wiki/Wikipedia:Requests_for_adminship
# /wiki/Wikipedia:Requested_articles
# /wiki/Wikipedia:Recent_additions
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eda0c1e0ef03> in <module>()
#      23                 pages.add(newPage)
#      24                 getLinks(newPage)
# ---> 25 getLinks("")  # first page
#
# <ipython-input-6-eda0c1e0ef03> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")  # first page
#
# <ipython-input-6-eda0c1e0ef03> in getLinks(pageUrl)
#      22                 print(newPage)
# ...

# %%
#practice-1

import requests
from bs4 import BeautifulSoup
import re

pages = set()

def getLinks(pageUrl):
    global pages
    
    res = requests.get('http://en.wikipedia.org'+pageUrl)
    soup = BeautifulSoup(res.text,'lxml')
    
    for link in soup.findAll('a', href = re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newpage = link.attrs['href']
               
                print(newpage)
                pages.add(newpage)
                getLinks(newpage)
getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Requesting_copyright_permission
# /wiki/Wikipedia:User_access_levels
# /wiki/Wikipedia:Requests_for_adminship
# /wiki/Wikipedia:Requested_articles
# /wiki/Wikipedia:Recent_additions
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/File:Seal_of_Kansas.svg
# /wiki/Special:WhatLinksHere/File:Seal_of_Kansas.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Category:Wikipedia_procedural_policies
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Consensus
# /wiki/Wikipedia:Conflict_of_interest
# ...

# %%
#2  crawling the site and listing tag element at meantime

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html, "html.parser")
    try:
        print(bsObj.h1.get_text())
        print(bsObj.find(id ="mw-content-text").findAll("p")[0])
        print(bsObj.find(id="ca-edit").find("span").find("a").attrs['href'])
    except AttributeError:  #當下頁面沒有上述定義標籤時，就印出
        #這頁有少東西，但是沒關係。
        print("This page is missing something! No worries though!")
    
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print("----------------\n"+newPage)
                pages.add(newPage)
                 getLinks(newPage)
getLinks("")

# %%
#3  launch from("http://oreilly.com") crawling page by page by page ...http

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bsObj, includeUrl):
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" or "www" that do
    #not contain the current URL
    for link in bsObj.findAll("a", href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def splitAddress(address):
    addressParts = address.replace("http://", "").split("/")
    return addressParts

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html, "html.parser")
    externalLinks = getExternalLinks(bsObj, splitAddress(startingPage)[0])
    if len(externalLinks) == 0:
        #沒有外部連結，在網站裡找一個
        internalLinks = getInternalLinks(startingPage)
        return getNextExternalLink(internalLinks[random.randint(0, 
                                  len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink("http://oreilly.com")
    print("Random external link is: "+externalLink)
    followExternalOnly(externalLink)
            
followExternalOnly("http://oreilly.com")
# Out:
# Random external link is: https://www.youtube.com/user/OreillyMedia
# Random external link is: http://fb.co/OReilly
# Random external link is: https://www.youtube.com/user/OreillyMedia
# Random external link is: http://fb.co/OReilly
# Random external link is: https://www.youtube.com/user/OreillyMedia
# Random external link is: https://www.youtube.com/user/OreillyMedia
# Random external link is: http://fb.co/OReilly
# Random external link is: http://twitter.com/oreillymedia
# Random external link is: https://cdn.oreillystatic.com/pdf/oreilly_high_performance_organizations_whitepaper.pdf
# Random external link is: http://fb.co/OReilly
# Random external link is: https://cdn.oreillystatic.com/pdf/oreilly_high_performance_organizations_whitepaper.pdf
# Random external link is: http://fb.co/OReilly
# Random external link is: http://twitter.com/oreillymedia
# Random external link is: https://cdn.oreillystatic.com/pdf/oreilly_high_performance_organizations_whitepaper.pdf
# ...

# %%
#5

from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bsObj, includeUrl):
    includeUrl = urlparse(includeUrl).scheme+"://"+urlparse(includeUrl).netloc
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith("/")):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" or "www" that do
    #not contain the current URL
    for link in bsObj.findAll("a", href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks


def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html, "html.parser")
    externalLinks = getExternalLinks(bsObj, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print("No external links, looking around the site for one")
        domain = urlparse(startingPage).scheme+"://"+urlparse(startingPage).netloc
        internalLinks = getInternalLinks(bsObj, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print("Random external link is: "+externalLink)
    followExternalOnly(externalLink)
            
#Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()
def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = urlparse(siteUrl).scheme+"://"+urlparse(siteUrl).netloc
    bsObj = BeautifulSoup(html, "html.parser")
    internalLinks = getInternalLinks(bsObj,domain)
    externalLinks = getExternalLinks(bsObj,domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)

followExternalOnly("http://oreilly.com")

allIntLinks.add("http://oreilly.com")
getAllExternalLinks("http://oreilly.com")
# Out:
# Random external link is: https://www.youtube.com/user/OreillyMedia
# Random external link is: http://oreilly.com
# Random external link is: http://fb.co/OReilly
# Random external link is: https://www.facebook.com/OReilly/likes?ref=page_internal
# Random external link is: https://th-th.facebook.com/OReilly/likes?ref=page_internal
# Random external link is: https://www.facebook.com/help/568137493302217
# Random external link is: https://ja-jp.facebook.com/help/568137493302217
# Random external link is: https://vi-vn.facebook.com/help/568137493302217
# Random external link is: https://id-id.facebook.com/help/568137493302217
# Random external link is: https://de-de.facebook.com/help/568137493302217
# Random external link is: https://ja-jp.facebook.com/help/568137493302217
# Random external link is: https://vi-vn.facebook.com/help/568137493302217
# ...

# %%
#46 scrapy

from scrapy.selector import Selector
from scrapy import Spider 
from wikiSpider.items import Article

class ArticleSpider(Spider):
    name ="article"
    allowed_domains = ["en.wikipedia.org"]
    Start_urls = ["http:en.wikipedia.org/wiki/Main_Page","http://en.wikipedia.org/wiki/Python_%28programming_language%29"]
    
    def parse(self, response):
        item = Article()
        title = response.xpath('//h1/text()')[0].extract()
        orint("Title is: "+title)
        item['title']= title
        return item
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-b4e8660cd7fd> in <module>()
#       1 #46 scrapy
#       2
# ----> 3 from scrapy.selector import Selector
#       4 from scrapy import Spider
#       5 from wikiSpider.items import Article
#
# ModuleNotFoundError: No module named 'scrapy'
